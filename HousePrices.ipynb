# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm as cm
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# %matplotlib inline

# %%
train = pd.read_csv("./dataset/house_prices/train.csv")
test = pd.read_csv("./dataset/house_prices/test.csv")

# %%
print(train.shape)
print(test.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %% [raw]
# This should probably be to do with the dependent variable or the label which is an extra column in the train set.

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.set_option('display.max_columns', 100)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [raw]
# The average sale price turns out to be roughly 180k $ and most values sit in between 130k $ and 215k $

# %% [markdown]
# Let's figure out the total NAN values of all the columns

# %%
nan = pd.concat([train.isnull().sum(), test.isnull().sum()], axis=1, keys=['Train', 'Test'])

# %%
nan[nan.sum(axis=1) > 0]
# Out:
#               Train    Test
# Alley          1369  1352.0
# BsmtCond         37    45.0
# BsmtExposure     38    44.0
# BsmtFinSF1        0     1.0
# BsmtFinSF2        0     1.0
# BsmtFinType1     37    42.0
# BsmtFinType2     38    42.0
# BsmtFullBath      0     2.0
# BsmtHalfBath      0     2.0
# BsmtQual         37    44.0
# BsmtUnfSF         0     1.0
# Electrical        1     0.0
# Exterior1st       0     1.0
# Exterior2nd       0     1.0
# Fence          1179  1169.0
# FireplaceQu     690   730.0
# Functional        0     2.0
# GarageArea        0     1.0
# GarageCars        0     1.0
# GarageCond       81    78.0
# GarageFinish     81    78.0
# GarageQual       81    78.0
# GarageType       81    76.0
# GarageYrBlt      81    78.0
# KitchenQual       0     1.0
# LotFrontage     259   227.0
# MSZoning          0     4.0
# MasVnrArea        8    15.0
# MasVnrType        8    16.0
# MiscFeature    1406  1408.0
# PoolQC         1453  1456.0
# SaleType          0     1.0
# ...

# %%
# Another way of finding the missing data
train.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageCond        81
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Utilities          0
# dtype: int64

# %% [raw]
# '''
# def correlation_matrix(df):
#
#     fig = plt.figure(figsize=(15,10))
#     ax1 = fig.add_subplot(111)
#     cmap = cm.get_cmap('jet', 30)
#     cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
#     ax1.grid(True)
#     plt.title('House Prices Feature Correlation')
#     labels=df.columns.tolist()
#     print(labels)
#     ax1.set_xticklabels(labels,fontsize=8)
#     ax1.set_yticklabels(labels,fontsize=8)
#     # Add colorbar, make sure to specify tick locations to match desired ticklabels
#     fig.colorbar(cax, ticks=[.55, .60, .65, .70, .75,.8,.85,.90,.95,1])
#     plt.show()
#
# correlation_matrix(features)
# '''

# %% [raw]
# train.corr()['SalePrice']

# %% [raw]
# '''
# to_be_kept = ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars']
# to_be_dropped = []
# for feature in features.columns.tolist():
#     if (features[feature].dtype == np.float64 or features[feature].dtype == np.int64) and feature not in to_be_kept:
#         to_be_dropped.append(feature)
# features.drop(to_be_dropped, axis=1, inplace=True)
# '''

# %% [raw]
# If we read the data description carefully, there is a combination of features. Some are numeric, some are string type and some are object.
#
# Let's work on each one of them so that our machine learning algorithms can handle them all
#
# numeric: no change required
# string: if there are categorical, we should use one hot encoding to separate them out, however, there are a lot of features and hence the feature matric may become very sparse, but we will handle them in later
# object: these types take up a lot of memory, and hence it is a better option to change their types accordingly

# %% [raw]
# Now, I have manually found out which are the categorical variables and will add them here, however, you can write some logic and decide which are and which are not.

# %% [markdown]
# Corelation matrix plot, since there are many features, we should be able to find out which ones provide max information. Darker the shade of color(red, blue), more is the corelation. Red corresponds to positive corelation and blue coresponds to negative corelation.

# %%
cormat = train.corr()

f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(cormat, vmax=.8, square=True)

# %% [markdown]
# Now, we have to find the top 'k' features that are corelated and build our model depending on them. Now, the important catch is to use the SalePrice as base for comparison.

# %%
cols = cormat.nlargest(10, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train[cols].values.T) #corelation matrix so that we print values along with colors
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10},
                 yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [raw]
# Looking at the above report card, we can say that,
# - OverallQual, GrLivArea are highly corelated to SalePrice
# - GarageCars and GarageArea are logically the same and hence, we will keep GarageCars owing to its higher corelation with SalePrice
# - Same is the case with TotalBsmtSF and 1stFlrSF
# - TotRmsAbvGrd and GrLivArea are again same and we will eliminate TotRmdAdvGrd

# %% [raw]
# Let's check some distributions which gives more info about the fields in the dataframe

# %% [raw]
# When performing regression, it is handly to perform log or box-cox transformations on the target variable. It helps improve the linearity of the data.

# %% [raw]
# Skewness of Sale Price

# %%
plt.hist(train.SalePrice)
# Out:
# (array([ 148.,  723.,  373.,  135.,   51.,   19.,    4.,    3.,    2.,    2.]),
#  array([  34900.,  106910.,  178920.,  250930.,  322940.,  394950.,
#          466960.,  538970.,  610980.,  682990.,  755000.]),
#  <a list of 10 Patch objects>)

# %%
print("Skew: "+ str(train.SalePrice.skew()))
# Out:
# Skew: 1.88287575977

# %%
# Log Transformation
target = np.log(train.SalePrice)
plt.hist(target)
# Out:
# (array([   5.,   12.,   54.,  184.,  470.,  400.,  220.,   90.,   19.,    6.]),
#  array([ 10.46024211,  10.7676652 ,  11.07508829,  11.38251138,
#          11.68993448,  11.99735757,  12.30478066,  12.61220375,
#          12.91962684,  13.22704994,  13.53447303]),
#  <a list of 10 Patch objects>)

# %%
print("Skew: "+ str(target.skew()))
# Out:
# Skew: 0.121335062205

# %% [raw]
# Working with numeric features

# %%
numeric_features = train.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %% [raw]
# Let's check back the corelation.

# %%
corr = numeric_features.corr()

print(corr['SalePrice'].sort_values(ascending=False)[1:6], '\n')
print(corr['SalePrice'].sort_values(ascending=False)[-5:],)
# Out:
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# Name: SalePrice, dtype: float64
#
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [raw]
# Let's take into account some categorical features as well. We will check if any 2 of the categorical variables are similar in meaning. For ex: age and birth year would be similar as using the birth year we can find the age. So, we can eliminate one of the two.
# We will perform a similar operation in case the categorical variables are similar.

# %%
categorical_features = train.select_dtypes(exclude=[np.number])
categorical_features.dtypes
# Out:
# MSZoning         object
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# ...

# %%
categorical_features.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1460         1460       1460       1460     1460       1460
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1382          225       1260       1445     1220        726
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1460     1460        1460        1460       1452      1460
# unique         6        8          15          16          4         4
# ...

# %% [raw]
# We will remove some features straightaway, 'Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'

# %%
remove_cat_features = ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
categorical_features.drop(remove_cat_features, axis=1, inplace=True)

# %%
categorical_features.describe()
# Out:
#        MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# count      1460   1460     1460        1460      1460      1460      1460
# unique        5      2        4           4         2         5         3
# top          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# freq       1151   1454      925        1311      1459      1052      1382
#
#        Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle  \
# count          1460       1460       1460     1460       1460      1460
# unique           25          9          8        5          8         6
# top           NAmes       Norm       Norm     1Fam     1Story     Gable
# freq            225       1260       1445     1220        726      1141
#
#        RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual ExterCond  \
# count      1460        1460        1460       1452      1460      1460
# unique        8          15          16          4         4         5
# ...

# %% [raw]
# Let's use one hot encoder and label encoder on the categorical variables!

# %%
oEncoder = OneHotEncoder()

# %%
lEncoder = LabelEncoder()

# %%
lEncoder.fit(categorical_features.MSZoning)
# Out:
# LabelEncoder()

# %%
mszoning = lEncoder.transform(categorical_features.MSZoning)

# %%
lEncoder.classes_[3]
# Out:
# 'RL'

# %%
mszoning
# Out:
# array([3, 3, 3, ..., 3, 3, 3])

# %%
categorical_features.MSZoning
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
# 5       RL
# 6       RL
# 7       RL
# 8       RM
# 9       RL
# 10      RL
# 11      RL
# 12      RL
# 13      RL
# 14      RL
# 15      RM
# 16      RL
# 17      RL
# 18      RL
# 19      RL
# 20      RL
# 21      RM
# 22      RL
# 23      RM
# 24      RL
# 25      RL
# 26      RL
# 27      RL
# 28      RL
# 29      RM
#         ..
# 1430    RL
# 1431    RL
# 1432    RL
# 1433    RL
# 1434    RL
# 1435    RL
# 1436    RL
# 1437    RL
# 1438    RM
# 1439    RL
# 1440    RL
# 1441    RM
# 1442    FV
# 1443    RL
# 1444    RL
# 1445    RL
# 1446    RL
# 1447    RL
# 1448    RL
# 1449    RM
# 1450    RL
# 1451    RL
# 1452    RM
# 1453    RL
# 1454    FV
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object
