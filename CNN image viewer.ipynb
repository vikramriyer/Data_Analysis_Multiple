# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from skimage import color
from scipy import ndimage
# %matplotlib inline

# %% [raw]
# Let's take vikram's img and check

# %%
img = cv2.imread("vikram.jpg")
img = color.rgb2gray(img)

# %%
img
# Out:
# array([[ 0.02352941,  0.00392157,  0.00392157, ...,  0.00392157,
#          0.00392157,  0.02745098],
#        [ 0.        ,  0.2627451 ,  0.25490196, ...,  0.25882353,
#          0.2627451 ,  0.        ],
#        [ 0.01960784,  0.8       ,  0.88235294, ...,  0.8745098 ,
#          0.8       ,  0.01568627],
#        ...,
#        [ 0.02213059,  0.8288349 ,  0.88148196, ...,  0.67139882,
#          0.77335961,  0.01649686],
#        [ 0.00280549,  0.28879725,  0.26020745, ...,  0.20249216,
#          0.2848451 ,  0.00361608],
#        [ 0.02605216,  0.00280549,  0.00922706, ...,  0.00529765,
#          0.00418157,  0.00865373]])

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (640, 540)

# %%
filters = np.array([[0,1,-1,0],[1,3,-3,-1],[1,3,-3,-1],[0,1,-1,0]])

# %%
filters.shape
# Out:
# (4, 4)

# %%
colvolved = ndimage.convolve(img, filters, mode='constant', cval=0.0)

# %%
plt.imshow(colvolved);
